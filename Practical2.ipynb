# %%
import pandas as pd

# %%
df = pd.read_csv('studentperform.txt')

# %%
df.head()
# Out:
#   Student ID   Name Gender  Math Marks  Science Marks  English Marks  \
# 0       S001  Aarav      M        78.0           85.0             82
# 1       S002   Diya      F        88.0           91.0             87
# 2       S003  Rohan      M        45.0           52.0             49
# 3       S004  Anaya      F        92.0           95.0             94
# 4       S005  Virat      M        15.0           22.0             18
#
#    Attendance Final Grade
# 0        92.0           A
# 1        95.0           A
# 2        60.0           C
# 3        98.0          A+
# 4        40.0           F

# %%
df.tail()
# Out:
#    Student ID    Name Gender  Math Marks  Science Marks  English Marks  \
# 13       S014  Simran      F        95.0           97.0             96
# 14       S015    Amit      M       150.0          140.0            145
# 15       S016    Riya      F        64.0           59.0             62
# 16       S017     Dev      M        83.0           78.0             80
# 17       S018   Tanvi      F         NaN           88.0             91
#
#     Attendance Final Grade
# 13        99.0          A+
# 14       110.0          A+
# 15       -10.0           C
# 16        92.0          B+
# 17        94.0           A

# %%
df.isnull().sum()
# Out:
# Student ID       0
# Name             0
# Gender           0
# Math Marks       1
# Science Marks    1
# English Marks    0
# Attendance       1
# Final Grade      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student ID     18 non-null     object
#  1   Name           18 non-null     object
#  2   Gender         18 non-null     object
#  3   Math Marks     17 non-null     float64
#  4   Science Marks  17 non-null     float64
#  5   English Marks  18 non-null     int64
#  6   Attendance     17 non-null     float64
#  7   Final Grade    18 non-null     object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 1.3+ KB

# %%
df.describe()
# Out:
#        Math Marks  Science Marks  English Marks  Attendance
# count   17.000000      17.000000      18.000000   17.000000
# mean    72.294118      73.764706      73.277778   76.352941
# std     36.271140      34.140389      34.008313   31.752837
# min      0.000000       5.000000       2.000000  -10.000000
# 25%     56.000000      59.000000      59.000000   60.000000
# 50%     78.000000      78.000000      79.500000   90.000000
# 75%     89.000000      93.000000      90.750000   95.000000
# max    150.000000     140.000000     145.000000  110.000000

# %%
math_mean = df['Math Marks'].mean()

# %%
print(math_mean)
# Out:
# 72.29411764705883

# %%
#print outliners (values above consider values above 100 as outliner)
for val in df['Science Marks']:
    if val>100:
        print("outliner : " , val)
# Out:
# outliner :  118.0
# outliner :  140.0

# %%
#print name of student sciemce mark more than 80 
df.loc[df['Science Marks'] > 80 , ["Name","Science Marks"] ]
# Out:
#       Name  Science Marks
# 0    Aarav           85.0
# 1     Diya           91.0
# 3    Anaya           95.0
# 6    Arjun          118.0
# 10    Neha           93.0
# 13  Simran           97.0
# 14    Amit          140.0
# 17   Tanvi           88.0

# %%
#plot a pairplot
import seaborn as sb
sb.pairplot(df)
